# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import SGDRegressor, BayesianRidge
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import accuracy_score as acc
	
from sklearn.metrics import balanced_accuracy_score as bacc  
from sklearn.metrics import make_scorer
from sklearn.dummy import DummyRegressor, DummyClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

# %% [markdown]
# #1. Loading the data

# %%
df_bank = pd.read_csv('https://raw.githubusercontent.com/NatalieB-github/CE888/master/lab3/bank-additional-full.csv', delimiter=";")

# %%
df_bank.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# #2. Data preprocessing:

# %% [markdown]
# ##2.1 Use LabelEncoder to convert the label into numbers.

# %%
df = df_bank.dropna()
df[["y"]] = df[["y"]].apply(LabelEncoder().fit_transform)
#df.drop(['Y_int'], axis=1,inplace=True)
df
# Out:
#        age          job  marital  ... euribor3m nr.employed  y
# 0       56    housemaid  married  ...     4.857      5191.0  0
# 1       57     services  married  ...     4.857      5191.0  0
# 2       37     services  married  ...     4.857      5191.0  0
# 3       40       admin.  married  ...     4.857      5191.0  0
# 4       56     services  married  ...     4.857      5191.0  0
# ...    ...          ...      ...  ...       ...         ... ..
# 41183   73      retired  married  ...     1.028      4963.6  1
# 41184   46  blue-collar  married  ...     1.028      4963.6  0
# 41185   56      retired  married  ...     1.028      4963.6  0
# 41186   44   technician  married  ...     1.028      4963.6  1
# 41187   74      retired  married  ...     1.028      4963.6  0
#
# [41188 rows x 21 columns]

# %% [markdown]
# ##2.2 Deleting the duration column

# %%
df.drop(['duration'], axis=1,inplace=True)
df
# Out:
#        age          job  marital  ... euribor3m nr.employed  y
# 0       56    housemaid  married  ...     4.857      5191.0  0
# 1       57     services  married  ...     4.857      5191.0  0
# 2       37     services  married  ...     4.857      5191.0  0
# 3       40       admin.  married  ...     4.857      5191.0  0
# 4       56     services  married  ...     4.857      5191.0  0
# ...    ...          ...      ...  ...       ...         ... ..
# 41183   73      retired  married  ...     1.028      4963.6  1
# 41184   46  blue-collar  married  ...     1.028      4963.6  0
# 41185   56      retired  married  ...     1.028      4963.6  0
# 41186   44   technician  married  ...     1.028      4963.6  1
# 41187   74      retired  married  ...     1.028      4963.6  0
#
# [41188 rows x 20 columns]

# %% [markdown]
# ##2.3 Perform one-hot encoding on the categorical features using pd.get_dummies(df)

# %%
df_dummies = pd.get_dummies(df)
df_dummies
# Out:
#        age  campaign  ...  poutcome_nonexistent  poutcome_success
# 0       56         1  ...                     1                 0
# 1       57         1  ...                     1                 0
# 2       37         1  ...                     1                 0
# 3       40         1  ...                     1                 0
# 4       56         1  ...                     1                 0
# ...    ...       ...  ...                   ...               ...
# 41183   73         1  ...                     1                 0
# 41184   46         1  ...                     1                 0
# 41185   56         2  ...                     1                 0
# 41186   44         1  ...                     1                 0
# 41187   74         3  ...                     0                 0
#
# [41188 rows x 63 columns]

# %% [markdown]
# ##2.4 Dropping rows with missing values

# %%
df_dummies.dropna(axis = 0, inplace = True)
df_dummies
# Out:
#        age  campaign  ...  poutcome_nonexistent  poutcome_success
# 0       56         1  ...                     1                 0
# 1       57         1  ...                     1                 0
# 2       37         1  ...                     1                 0
# 3       40         1  ...                     1                 0
# 4       56         1  ...                     1                 0
# ...    ...       ...  ...                   ...               ...
# 41183   73         1  ...                     1                 0
# 41184   46         1  ...                     1                 0
# 41185   56         2  ...                     1                 0
# 41186   44         1  ...                     1                 0
# 41187   74         3  ...                     0                 0
#
# [41188 rows x 63 columns]

# %% [markdown]
# ##2.5 Plot histogram of the label and calculate the imbalance in the dataset.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x = 'y', data = df_bank)

# %%
total = df['y'].value_counts()
(total[1]/(total[0]+total[1]))*100
#significantly more 'no' than 'yes'= imbalanced?
# Out:
# 11.265417111780131

# %% [markdown]
# #3.  Modeling the data

# %% [markdown]
# ##3.1 Train-test-split

# %%
x = df_dummies.iloc[:, df_dummies.columns != 'y'].to_numpy()
y = df_dummies.iloc[:, df_dummies.columns == 'y'].to_numpy()

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=50, stratify=y)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (32950, 62)
# (8238, 62)
# (32950, 1)
# (8238, 1)

# %% [markdown]
# ##3.2 Random forest classifier

# %%
fold = 10
trees = 100
depth = 3

clf = RandomForestClassifier(n_estimators=trees, max_depth=depth, random_state=50)
scores = cross_val_score(clf, x_train, y_train, cv=fold, scoring='accuracy')
print("ACC: %.2f +/- %.2f" % (scores.mean(), scores.std()))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...

# %% [markdown]
# ##3.3 Dummy Classifier

# %%
clf_dummy = DummyClassifier(strategy="stratified", random_state = 50)

clf_dummy.fit(x_train, y_train)
scores_dummy = cross_val_score(clf_dummy, x_train, y_train, cv=fold, scoring='accuracy')
print("ACC: %.2f +/- %.2f" % (scores_dummy.mean(), scores_dummy.std()))
# Out:
# ACC: 0.79 +/- 0.00

# %% [markdown]
# ##3.4 Use GridSearchCV for random forest classifier

# %%
clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 3,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 50,
#  'verbose': 0,
#  'warm_start': False}

# %%
param_grid = {'n_estimators': [100, 200, 300, 1000],  
              'max_depth': [3, 6, 9, 12,15],}

clf = RandomForestClassifier()

grid = GridSearchCV(estimator=clf, param_grid=param_grid, scoring='accuracy', n_jobs=-1,cv=10) 
#
#print(grid.best_params_) 
#grid_predictions = grid.predict(X_test)

# %%
grid.fit(x_train, y_train)
grid_search.best_params_

# %%
grid_predictions = grid.predict(x_test)
print(classification_report(y_test, grid_predictions))

# %% [markdown]
# ##3.5 Top 3 features
